# %%
# Kafka Consumer → SQLite
# ------------------------
# This script consumes basket data from Kafka and stores it in an SQLite database
# for later analysis (e.g., clustering, prediction, web dashboard).

import sqlite3
import json
import time
from kafka import KafkaConsumer
from datetime import datetime, timezone

# SQLite setup
conn = sqlite3.connect("baskets.db")
cursor = conn.cursor()

# Create tables if they don't exist
cursor.execute("""
CREATE TABLE IF NOT EXISTS baskets (
    id INTEGER PRIMARY KEY AUTOINCREMENT,
    timestamp TEXT
);
""")

cursor.execute("""
CREATE TABLE IF NOT EXISTS basket_items (
    id INTEGER PRIMARY KEY AUTOINCREMENT,
    basket_id INTEGER,
    item TEXT,
    FOREIGN KEY(basket_id) REFERENCES baskets(id)
);
""")
conn.commit()

# Kafka consumer setup
consumer = KafkaConsumer(
    'baskets',
    bootstrap_servers='localhost:9092',
    auto_offset_reset='earliest',
    value_deserializer=lambda v: json.loads(v.decode('utf-8')),
    group_id='basket-db-writer'
)

print("📡 Listening for basket data from Kafka...")

try:
    for message in consumer:
        data = message.value
        items = data.get("items", [])
        timestamp = datetime.fromtimestamp(data.get("timestamp", time.time()), timezone.utc).isoformat()

        # Insert basket and get its ID
        cursor.execute("INSERT INTO baskets (timestamp) VALUES (?)", (timestamp,))
        basket_id = cursor.lastrowid

        # Insert items
        cursor.executemany(
            "INSERT INTO basket_items (basket_id, item) VALUES (?, ?)",
            [(basket_id, item) for item in items]
        )

        conn.commit()
        print(f"✅ Stored basket with {len(items)} items @ {timestamp}")

except KeyboardInterrupt:
    print("⛔ Consumer stopped.")

finally:
    consumer.close()
    conn.close()
# Out:
# 📡 Listening for basket data from Kafka...
# ✅ Stored basket with 4 items @ 2025-05-29T09:04:30.373390+00:00
# ✅ Stored basket with 3 items @ 2025-05-29T09:04:31.502320+00:00
# ✅ Stored basket with 1 items @ 2025-05-29T09:04:32.504750+00:00
# ✅ Stored basket with 4 items @ 2025-05-29T09:04:33.506624+00:00
# ✅ Stored basket with 4 items @ 2025-05-29T09:04:34.510239+00:00
# ✅ Stored basket with 5 items @ 2025-05-29T09:04:35.511985+00:00
# ✅ Stored basket with 1 items @ 2025-05-29T09:04:36.514248+00:00
# ✅ Stored basket with 5 items @ 2025-05-29T09:04:37.516573+00:00
# ✅ Stored basket with 1 items @ 2025-05-29T09:04:38.517461+00:00
# ✅ Stored basket with 2 items @ 2025-05-29T09:04:39.518453+00:00
# ✅ Stored basket with 5 items @ 2025-05-29T09:04:40.519610+00:00
# ✅ Stored basket with 9 items @ 2025-05-29T09:04:41.520903+00:00
# ✅ Stored basket with 1 items @ 2025-05-29T09:04:42.524303+00:00
# ✅ Stored basket with 3 items @ 2025-05-29T09:04:43.527026+00:00
# ✅ Stored basket with 2 items @ 2025-05-29T09:04:44.527836+00:00
# ✅ Stored basket with 4 items @ 2025-05-29T09:04:45.528551+00:00
# ✅ Stored basket with 1 items @ 2025-05-29T09:04:46.529511+00:00
# ✅ Stored basket with 1 items @ 2025-05-29T09:04:47.530562+00:00
# ✅ Stored basket with 1 items @ 2025-05-29T09:04:48.531692+00:00
# ✅ Stored basket with 1 items @ 2025-05-29T09:04:49.532964+00:00
# ✅ Stored basket with 1 items @ 2025-05-29T09:04:50.534866+00:00
# ✅ Stored basket with 2 items @ 2025-05-29T09:04:51.535691+00:00
# ✅ Stored basket with 1 items @ 2025-05-29T09:04:52.537738+00:00
# ✅ Stored basket with 5 items @ 2025-05-29T09:04:53.545168+00:00
# ✅ Stored basket with 11 items @ 2025-05-29T09:04:54.545986+00:00
# ✅ Stored basket with 2 items @ 2025-05-29T09:04:55.547839+00:00
# ✅ Stored basket with 1 items @ 2025-05-29T09:04:56.549791+00:00
# ✅ Stored basket with 4 items @ 2025-05-29T09:04:57.550556+00:00
# ✅ Stored basket with 1 items @ 2025-05-29T09:04:58.552375+00:00
# ✅ Stored basket with 6 items @ 2025-05-29T09:04:59.553605+00:00
# ✅ Stored basket with 4 items @ 2025-05-29T09:05:00.554971+00:00
# ✅ Stored basket with 7 items @ 2025-05-29T09:05:01.555910+00:00
# ✅ Stored basket with 5 items @ 2025-05-29T09:05:02.557018+00:00
# ✅ Stored basket with 8 items @ 2025-05-29T09:05:03.557707+00:00
# ✅ Stored basket with 3 items @ 2025-05-29T09:05:04.560212+00:00
# ✅ Stored basket with 2 items @ 2025-05-29T09:05:05.561782+00:00
# ✅ Stored basket with 1 items @ 2025-05-29T09:05:06.562537+00:00
# ✅ Stored basket with 1 items @ 2025-05-29T09:05:07.563680+00:00
# ✅ Stored basket with 4 items @ 2025-05-29T09:05:08.567299+00:00
# ✅ Stored basket with 3 items @ 2025-05-29T09:05:09.568897+00:00
# ✅ Stored basket with 6 items @ 2025-05-29T09:05:10.570387+00:00
# ✅ Stored basket with 13 items @ 2025-05-29T09:05:11.572158+00:00
# ✅ Stored basket with 2 items @ 2025-05-29T09:05:12.572862+00:00
# ✅ Stored basket with 1 items @ 2025-05-29T09:05:13.575452+00:00
# ✅ Stored basket with 8 items @ 2025-05-29T09:05:14.576238+00:00
# ✅ Stored basket with 1 items @ 2025-05-29T09:05:15.578471+00:00
# ✅ Stored basket with 2 items @ 2025-05-29T09:05:16.579521+00:00
# ✅ Stored basket with 1 items @ 2025-05-29T09:05:17.580483+00:00
# ✅ Stored basket with 1 items @ 2025-05-29T09:05:18.581398+00:00
# ✅ Stored basket with 10 items @ 2025-05-29T09:05:19.582097+00:00
# ✅ Stored basket with 4 items @ 2025-05-29T09:05:20.585272+00:00
# ✅ Stored basket with 1 items @ 2025-05-29T09:05:21.586505+00:00
# ✅ Stored basket with 4 items @ 2025-05-29T09:05:22.588063+00:00
# ✅ Stored basket with 10 items @ 2025-05-29T09:05:23.589329+00:00
# ✅ Stored basket with 5 items @ 2025-05-29T09:05:24.592109+00:00
# ✅ Stored basket with 4 items @ 2025-05-29T09:05:25.593697+00:00
# ✅ Stored basket with 3 items @ 2025-05-29T09:05:26.594908+00:00
# ✅ Stored basket with 7 items @ 2025-05-29T09:05:27.595890+00:00
# ✅ Stored basket with 6 items @ 2025-05-29T09:05:28.596556+00:00
# ✅ Stored basket with 3 items @ 2025-05-29T09:05:29.597314+00:00
# ✅ Stored basket with 7 items @ 2025-05-29T09:05:30.598798+00:00
# ✅ Stored basket with 2 items @ 2025-05-29T09:05:31.599797+00:00
# ✅ Stored basket with 3 items @ 2025-05-29T09:05:32.600888+00:00
# ✅ Stored basket with 5 items @ 2025-05-29T09:05:33.602365+00:00
# ✅ Stored basket with 3 items @ 2025-05-29T09:05:34.603273+00:00
# ✅ Stored basket with 1 items @ 2025-05-29T09:05:35.604725+00:00
# ✅ Stored basket with 2 items @ 2025-05-29T09:05:36.605786+00:00
# ✅ Stored basket with 2 items @ 2025-05-29T09:05:37.606560+00:00
# ✅ Stored basket with 3 items @ 2025-05-29T09:05:38.607898+00:00
# ✅ Stored basket with 8 items @ 2025-05-29T09:05:39.610322+00:00
# ✅ Stored basket with 1 items @ 2025-05-29T09:05:40.611693+00:00
# ✅ Stored basket with 7 items @ 2025-05-29T09:05:41.612960+00:00
# ✅ Stored basket with 8 items @ 2025-05-29T09:05:42.613746+00:00
# ✅ Stored basket with 3 items @ 2025-05-29T09:05:43.614451+00:00
# ✅ Stored basket with 1 items @ 2025-05-29T09:05:44.615760+00:00
# ✅ Stored basket with 4 items @ 2025-05-29T09:05:45.617255+00:00
# ✅ Stored basket with 5 items @ 2025-05-29T09:05:46.618551+00:00
# ✅ Stored basket with 5 items @ 2025-05-29T09:05:47.619497+00:00
# ✅ Stored basket with 4 items @ 2025-05-29T09:05:48.620670+00:00
# ✅ Stored basket with 2 items @ 2025-05-29T09:05:49.621425+00:00
# ✅ Stored basket with 1 items @ 2025-05-29T09:05:50.622907+00:00
# ✅ Stored basket with 10 items @ 2025-05-29T09:05:51.624374+00:00
# ✅ Stored basket with 4 items @ 2025-05-29T09:05:52.624936+00:00
# ✅ Stored basket with 7 items @ 2025-05-29T09:05:53.625928+00:00
# ✅ Stored basket with 1 items @ 2025-05-29T09:05:54.626549+00:00
# ✅ Stored basket with 7 items @ 2025-05-29T09:05:55.627621+00:00
# ✅ Stored basket with 2 items @ 2025-05-29T09:05:56.628624+00:00
# ✅ Stored basket with 3 items @ 2025-05-29T09:05:57.629338+00:00
# ✅ Stored basket with 2 items @ 2025-05-29T09:05:58.630500+00:00
# ✅ Stored basket with 1 items @ 2025-05-29T09:05:59.631311+00:00
# ✅ Stored basket with 1 items @ 2025-05-29T09:06:00.631922+00:00
# ✅ Stored basket with 3 items @ 2025-05-29T09:06:01.632415+00:00
# ✅ Stored basket with 4 items @ 2025-05-29T09:06:02.633110+00:00
# ✅ Stored basket with 9 items @ 2025-05-29T09:06:03.633662+00:00
# ✅ Stored basket with 1 items @ 2025-05-29T09:06:04.634859+00:00
# ✅ Stored basket with 2 items @ 2025-05-29T09:06:05.636065+00:00
# ✅ Stored basket with 9 items @ 2025-05-29T09:06:06.636909+00:00
# ✅ Stored basket with 10 items @ 2025-05-29T09:06:07.638351+00:00
# ✅ Stored basket with 3 items @ 2025-05-29T09:06:08.639072+00:00
# ✅ Stored basket with 2 items @ 2025-05-29T09:06:09.640600+00:00
# ✅ Stored basket with 2 items @ 2025-05-29T09:06:10.641561+00:00
# ✅ Stored basket with 9 items @ 2025-05-29T09:06:11.643026+00:00
# ✅ Stored basket with 3 items @ 2025-05-29T09:06:12.643698+00:00
# ✅ Stored basket with 10 items @ 2025-05-29T09:06:13.644908+00:00
# ✅ Stored basket with 1 items @ 2025-05-29T09:06:14.645583+00:00
# ✅ Stored basket with 2 items @ 2025-05-29T09:06:15.646354+00:00
# ✅ Stored basket with 6 items @ 2025-05-29T09:06:16.647685+00:00
# ✅ Stored basket with 7 items @ 2025-05-29T09:06:17.649231+00:00
# ✅ Stored basket with 1 items @ 2025-05-29T09:06:18.650001+00:00
# ✅ Stored basket with 2 items @ 2025-05-29T09:06:19.651139+00:00
# ✅ Stored basket with 10 items @ 2025-05-29T09:06:20.652297+00:00
# ✅ Stored basket with 2 items @ 2025-05-29T09:06:21.653322+00:00
# ✅ Stored basket with 8 items @ 2025-05-29T09:06:22.654314+00:00
# ✅ Stored basket with 2 items @ 2025-05-29T09:06:23.655885+00:00
# ✅ Stored basket with 4 items @ 2025-05-29T09:06:24.657228+00:00
# ✅ Stored basket with 3 items @ 2025-05-29T09:06:25.659889+00:00
# ✅ Stored basket with 6 items @ 2025-05-29T09:06:26.664656+00:00
# ✅ Stored basket with 7 items @ 2025-05-29T09:06:27.667069+00:00
# ✅ Stored basket with 3 items @ 2025-05-29T09:06:28.667581+00:00
# ✅ Stored basket with 8 items @ 2025-05-29T09:06:29.668585+00:00
# ✅ Stored basket with 4 items @ 2025-05-29T09:06:30.670170+00:00
# ✅ Stored basket with 4 items @ 2025-05-29T09:06:31.671299+00:00
# ✅ Stored basket with 2 items @ 2025-05-29T09:06:32.674022+00:00
# ✅ Stored basket with 2 items @ 2025-05-29T09:06:33.675299+00:00
# ✅ Stored basket with 1 items @ 2025-05-29T09:06:34.676532+00:00
# ✅ Stored basket with 15 items @ 2025-05-29T09:06:35.678005+00:00
# ✅ Stored basket with 1 items @ 2025-05-29T09:06:36.681930+00:00
# ✅ Stored basket with 1 items @ 2025-05-29T09:06:37.683453+00:00
# ✅ Stored basket with 3 items @ 2025-05-29T09:06:38.687788+00:00
# ✅ Stored basket with 1 items @ 2025-05-29T09:06:39.689401+00:00
# ✅ Stored basket with 2 items @ 2025-05-29T09:06:40.690627+00:00
# ✅ Stored basket with 5 items @ 2025-05-29T09:06:41.693988+00:00
# ✅ Stored basket with 1 items @ 2025-05-29T09:06:42.694781+00:00
# ✅ Stored basket with 2 items @ 2025-05-29T09:06:43.695957+00:00
# ✅ Stored basket with 3 items @ 2025-05-29T09:06:44.697348+00:00
# ✅ Stored basket with 3 items @ 2025-05-29T09:06:45.699041+00:00
# ✅ Stored basket with 1 items @ 2025-05-29T09:06:46.701517+00:00
# ✅ Stored basket with 2 items @ 2025-05-29T09:06:47.703408+00:00
# ✅ Stored basket with 1 items @ 2025-05-29T09:06:48.705357+00:00
# ✅ Stored basket with 1 items @ 2025-05-29T09:06:49.707216+00:00
# ✅ Stored basket with 5 items @ 2025-05-29T09:06:50.709329+00:00
# ✅ Stored basket with 3 items @ 2025-05-29T09:06:51.712246+00:00
# ✅ Stored basket with 2 items @ 2025-05-29T09:06:52.713072+00:00
# ✅ Stored basket with 1 items @ 2025-05-29T09:06:53.713569+00:00
# ✅ Stored basket with 7 items @ 2025-05-29T09:06:54.716449+00:00
# ✅ Stored basket with 2 items @ 2025-05-29T09:06:55.717720+00:00
# ✅ Stored basket with 10 items @ 2025-05-29T09:06:56.719050+00:00
# ✅ Stored basket with 5 items @ 2025-05-29T09:06:57.722677+00:00
# ✅ Stored basket with 6 items @ 2025-05-29T09:06:58.724254+00:00
# ✅ Stored basket with 2 items @ 2025-05-29T09:06:59.725421+00:00
# ✅ Stored basket with 6 items @ 2025-05-29T09:07:00.727770+00:00
# ✅ Stored basket with 7 items @ 2025-05-29T09:07:01.730612+00:00
# ✅ Stored basket with 1 items @ 2025-05-29T09:07:02.732478+00:00
# ✅ Stored basket with 6 items @ 2025-05-29T09:07:03.733405+00:00
# ✅ Stored basket with 9 items @ 2025-05-29T09:07:04.738193+00:00
# ✅ Stored basket with 2 items @ 2025-05-29T09:07:05.739661+00:00
# ✅ Stored basket with 1 items @ 2025-05-29T09:07:06.740443+00:00
# ✅ Stored basket with 5 items @ 2025-05-29T09:07:07.742630+00:00
# ✅ Stored basket with 5 items @ 2025-05-29T09:07:08.747666+00:00
# ✅ Stored basket with 5 items @ 2025-05-29T09:07:09.748937+00:00
# ✅ Stored basket with 4 items @ 2025-05-29T09:07:10.750474+00:00
# ✅ Stored basket with 3 items @ 2025-05-29T09:07:11.751559+00:00
# ✅ Stored basket with 3 items @ 2025-05-29T09:07:12.752336+00:00
# ✅ Stored basket with 1 items @ 2025-05-29T09:07:13.755153+00:00
# ✅ Stored basket with 4 items @ 2025-05-29T09:07:14.756283+00:00
# ✅ Stored basket with 2 items @ 2025-05-29T09:07:15.758459+00:00
# ✅ Stored basket with 3 items @ 2025-05-29T09:07:16.760318+00:00
# ✅ Stored basket with 3 items @ 2025-05-29T09:07:17.761596+00:00
# ✅ Stored basket with 3 items @ 2025-05-29T09:07:18.763175+00:00
# ✅ Stored basket with 1 items @ 2025-05-29T09:07:19.765258+00:00
# ✅ Stored basket with 8 items @ 2025-05-29T09:07:20.767684+00:00
# ✅ Stored basket with 1 items @ 2025-05-29T09:07:21.769742+00:00
# ✅ Stored basket with 5 items @ 2025-05-29T09:07:22.771600+00:00
# ✅ Stored basket with 1 items @ 2025-05-29T09:07:23.774983+00:00
# ✅ Stored basket with 8 items @ 2025-05-29T09:07:24.775360+00:00
# ✅ Stored basket with 4 items @ 2025-05-29T09:07:25.780254+00:00
# ✅ Stored basket with 2 items @ 2025-05-29T09:07:26.786111+00:00
# ✅ Stored basket with 2 items @ 2025-05-29T09:07:27.788405+00:00
# ✅ Stored basket with 3 items @ 2025-05-29T09:07:28.790822+00:00
# ✅ Stored basket with 5 items @ 2025-05-29T09:07:29.792441+00:00
# ✅ Stored basket with 3 items @ 2025-05-29T09:07:30.795208+00:00
# ✅ Stored basket with 2 items @ 2025-05-29T09:07:31.798140+00:00
# ✅ Stored basket with 2 items @ 2025-05-29T09:07:32.800720+00:00
# ✅ Stored basket with 4 items @ 2025-05-29T09:07:33.802163+00:00
# ✅ Stored basket with 2 items @ 2025-05-29T09:07:34.804761+00:00
# ✅ Stored basket with 23 items @ 2025-05-29T09:07:35.806487+00:00
# ✅ Stored basket with 2 items @ 2025-05-29T09:07:36.807748+00:00
# ✅ Stored basket with 7 items @ 2025-05-29T09:07:37.810321+00:00
# ✅ Stored basket with 6 items @ 2025-05-29T09:07:38.811956+00:00
# ✅ Stored basket with 1 items @ 2025-05-29T09:07:39.815985+00:00
# ✅ Stored basket with 1 items @ 2025-05-29T09:07:40.817434+00:00
# ✅ Stored basket with 1 items @ 2025-05-29T09:07:41.819102+00:00
# ✅ Stored basket with 5 items @ 2025-05-29T09:07:42.819973+00:00
# ✅ Stored basket with 2 items @ 2025-05-29T09:07:43.822802+00:00
# ✅ Stored basket with 1 items @ 2025-05-29T09:07:44.827948+00:00
# ✅ Stored basket with 7 items @ 2025-05-29T09:07:45.830888+00:00
# ✅ Stored basket with 1 items @ 2025-05-29T09:07:46.831450+00:00
# ✅ Stored basket with 5 items @ 2025-05-29T09:07:47.833135+00:00
# ✅ Stored basket with 5 items @ 2025-05-29T09:07:48.834635+00:00
# ✅ Stored basket with 3 items @ 2025-05-29T09:07:49.836447+00:00
# ✅ Stored basket with 1 items @ 2025-05-29T09:07:50.838529+00:00
# ✅ Stored basket with 1 items @ 2025-05-29T09:07:51.839402+00:00
# ✅ Stored basket with 2 items @ 2025-05-29T09:07:52.840919+00:00
# ✅ Stored basket with 1 items @ 2025-05-29T09:07:53.842187+00:00
# ✅ Stored basket with 3 items @ 2025-05-29T09:07:54.844986+00:00
# ✅ Stored basket with 2 items @ 2025-05-29T09:07:55.847375+00:00
# ✅ Stored basket with 5 items @ 2025-05-29T09:07:56.848736+00:00
# ✅ Stored basket with 2 items @ 2025-05-29T09:07:57.850866+00:00
# ✅ Stored basket with 1 items @ 2025-05-29T09:07:58.852634+00:00
# ✅ Stored basket with 3 items @ 2025-05-29T09:07:59.853606+00:00
# ✅ Stored basket with 6 items @ 2025-05-29T09:08:00.855997+00:00
# ✅ Stored basket with 4 items @ 2025-05-29T09:08:01.857327+00:00
# ✅ Stored basket with 5 items @ 2025-05-29T09:08:02.858127+00:00
# ✅ Stored basket with 4 items @ 2025-05-29T09:08:03.858775+00:00
# ✅ Stored basket with 6 items @ 2025-05-29T09:08:04.861685+00:00
# ✅ Stored basket with 1 items @ 2025-05-29T09:08:05.864130+00:00
# ✅ Stored basket with 2 items @ 2025-05-29T09:08:06.864950+00:00
# ✅ Stored basket with 2 items @ 2025-05-29T09:08:07.866359+00:00
# ✅ Stored basket with 1 items @ 2025-05-29T09:08:08.868605+00:00
# ✅ Stored basket with 2 items @ 2025-05-29T09:08:09.870173+00:00
# ✅ Stored basket with 4 items @ 2025-05-29T09:08:10.871561+00:00
# ✅ Stored basket with 1 items @ 2025-05-29T09:08:11.874057+00:00
# ✅ Stored basket with 12 items @ 2025-05-29T09:08:12.874643+00:00
# ✅ Stored basket with 2 items @ 2025-05-29T09:08:13.875538+00:00
# ✅ Stored basket with 1 items @ 2025-05-29T09:08:14.880273+00:00
# ✅ Stored basket with 6 items @ 2025-05-29T09:08:15.881540+00:00
# ✅ Stored basket with 4 items @ 2025-05-29T09:08:16.883106+00:00
# ✅ Stored basket with 8 items @ 2025-05-29T09:08:17.884673+00:00
# ✅ Stored basket with 3 items @ 2025-05-29T09:08:18.885495+00:00
# ✅ Stored basket with 1 items @ 2025-05-29T09:08:19.886929+00:00
# ✅ Stored basket with 6 items @ 2025-05-29T09:08:20.888398+00:00
# ✅ Stored basket with 12 items @ 2025-05-29T09:08:21.889986+00:00
# ✅ Stored basket with 3 items @ 2025-05-29T09:08:22.894537+00:00
# ✅ Stored basket with 8 items @ 2025-05-29T09:08:23.896428+00:00
# ✅ Stored basket with 9 items @ 2025-05-29T09:08:24.897197+00:00
# ✅ Stored basket with 4 items @ 2025-05-29T09:08:25.898802+00:00
# ✅ Stored basket with 5 items @ 2025-05-29T09:08:26.900269+00:00
# ✅ Stored basket with 6 items @ 2025-05-29T09:08:27.901752+00:00
# ✅ Stored basket with 4 items @ 2025-05-29T09:08:28.902821+00:00
# ⛔ Consumer stopped.
